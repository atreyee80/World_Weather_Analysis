# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from gmaps) (7.22.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: six in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: pickleshare in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: decorator in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (3.0.18)
# Requirement already satisfied: appnope in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: pygments in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (47.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: jupyter-client in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.1)
# Requirement already satisfied: ipython-genutils in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: nbconvert in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: argon2-cffi in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (22.0.3)
# Requirement already satisfied: jinja2 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: prometheus-client in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.10.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.5)
# Requirement already satisfied: pycparser in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: bleach in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: defusedxml in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: async-generator in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: packaging in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.9)
# Requirement already satisfied: webencodings in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/saha/Desktop/Resources1/env/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID    City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  Albany      US  42.6001  -73.9662     55.00        84          99
# 1        1   Tiksi      RU  71.6872  128.8694     19.78        84          83
# 2        2  Castro      BR -24.7911  -50.0119     55.29        96          55
# 3        3  Kodiak      US  57.7900 -152.4072     37.40        87          90
# 4        4  Hobart      AU -42.8794  147.3294     64.40        42          75
#
#    Wind Speed Current Description
# 0        2.35     overcast clouds
# 1        8.48       broken clouds
# 2        7.67       broken clouds
# 3       11.50       moderate rain
# 4       28.77       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 20
# What is the maximum temperature you would like for your trip? 40

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3           Kodiak      US  57.7900 -152.4072     37.40        87
# 13       13        Neryungri      RU  56.6709  124.6491     22.37        69
# 43       43  Haines Junction      CA  60.7522 -137.5108     37.40        60
# 46       46       Skibbereen      IE  51.5500   -9.2667     39.20       100
# 48       48          Okhotsk      RU  59.3833  143.3000     24.96        55
# 63       63        Ilulissat      GL  69.2167  -51.1000     21.20        93
# 68       68       Nikolskoye      RU  59.7035   30.7861     39.99        75
# 73       73           Nivala      FI  63.9167   24.9667     32.23        88
# 78       78         Tasiilaq      GL  65.6145  -37.6368     28.40        74
# 82       82      Bronnoysund      NO  65.4625   12.1997     37.40        87
#
#     Cloudiness  Wind Speed Current Description
# 3           90       11.50       moderate rain
# 13          79        3.15       broken clouds
# 43          98        6.91     overcast clouds
# 46          75        3.44                 fog
# 48         100       11.25     overcast clouds
# 63          90       11.50     overcast clouds
# 68          90        8.95          light rain
# 73          79        7.94       broken clouds
# 78          49        9.22    scattered clouds
# 82          75       12.66       broken clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                124
# City                   124
# Country                124
# Lat                    124
# Lng                    124
# Max Temp               124
# Humidity               124
# Cloudiness             124
# Wind Speed             124
# Current Description    124
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
#preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 3            Kodiak      US     37.40       moderate rain  57.7900 -152.4072
# 13        Neryungri      RU     22.37       broken clouds  56.6709  124.6491
# 43  Haines Junction      CA     37.40     overcast clouds  60.7522 -137.5108
# 46       Skibbereen      IE     39.20                 fog  51.5500   -9.2667
# 48          Okhotsk      RU     24.96     overcast clouds  59.3833  143.3000
# 63        Ilulissat      GL     21.20     overcast clouds  69.2167  -51.1000
# 68       Nikolskoye      RU     39.99          light rain  59.7035   30.7861
# 73           Nivala      FI     32.23       broken clouds  63.9167   24.9667
# 78         Tasiilaq      GL     28.40    scattered clouds  65.6145  -37.6368
# 82      Bronnoysund      NO     37.40       broken clouds  65.4625   12.1997
#
#    Hotel Name
# 3
# 13
# 43
# 46
# 48
# 63
# 68
# 73
# 78
# 82

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
   
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}" 
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
   
    # 6e. Make request and retrieve the JSON data from the search. 
    
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    
    # Grab the first hotel from the results and store the name.
    #hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")
clean_hotel_df;

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)




# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Save figure
import matplotlib.pyplot as plt
plt.savefig("Vacation_Search/Hotel_listings.png")
